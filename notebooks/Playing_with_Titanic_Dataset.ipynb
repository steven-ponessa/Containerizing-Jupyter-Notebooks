# %% [markdown]
# # Data Analysis - Playing with Titanic Dataset
# by Steve Ponessa ([@ponessa](https://twitter.com/ponessa)), May 2021
# <img src="img/jupyter.png" alt="Jupyter Image" width="10%">
#
#
# ---
#
# See:
# [Getting started with Data Analysis with Python Pandas](https://towardsdatascience.com/getting-started-to-data-analysis-with-python-pandas-with-titanic-dataset-a195ab043c77
# )
#
# ---
#
# The "Titanic" dataset was retrived from Kaggle and the link can be found below:
#
# [Titanic Dataset](https://www.kaggle.com/c/titanic/data)
#
#
#
# ---

# %% [markdown]
# # Importing the dataset with read_csv and displaying the data.

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

df = pd.read_csv("data/titanic-train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **Using Head and Tail methods inorder to display the data.**

# %%
df.head(5)  # Used to display top 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(5) # Used to display last 5
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # Accessing specific coloums which are needed.

# %%
df = pd.read_csv("data/titanic-train.csv", usecols= ["PassengerId", "Survived", "Pclass", "Name", "Sex","Age"])
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %% [markdown]
# # Get more information about the database by using describe method.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age
# count   891.000000  891.000000  891.000000  714.000000
# mean    446.000000    0.383838    2.308642   29.699118
# std     257.353842    0.486592    0.836071   14.526497
# min       1.000000    0.000000    1.000000    0.420000
# 25%     223.500000    0.000000    2.000000   20.125000
# 50%     446.000000    0.000000    3.000000   28.000000
# 75%     668.500000    1.000000    3.000000   38.000000
# max     891.000000    1.000000    3.000000   80.000000

# %% [markdown]
# # Sorting the values by using the sort method.

# %%
df.sort_values("Age")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %% [markdown]
# # Sorting the values according to the age.

# %%
df = df.sort_values("Age", ascending = False)
df.head(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age
# 630  male  80.0
# 851  male  74.0
# 493  male  71.0
# 96   male  71.0
# 116  male  70.5

# %% [markdown]
# # Filtering the dataset, or cleaning the dataset by selecting only the name and many more.

# %%
result = df[df['Name'] ==  'Svensson, Mr. Johan']
result
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age
# 851          852         0       3  Svensson, Mr. Johan  male  74.0

# %% [markdown]
# # Counting the occurences of variables

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# # Using .nunique() to count number of unique values that occur in dataset or in a column

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# dtype: int64

# %% [markdown]
# # Filtering

# %% [markdown]
# **AND operator**

# %%
df_age = df["Age"] < 50
df_sex_mask = df["Sex"] == "female"
df[df_age & df_sex_mask]
# Out:
#      PassengerId  Survived  Pclass  \
# 52            53         1       1
# 796          797         1       1
# 754          755         1       2
# 556          557         1       1
# 736          737         0       3
# ..           ...       ...     ...
# 119          120         0       3
# 381          382         1       3
# 172          173         1       3
# 644          645         1       3
# 469          470         1       3
#
#                                                   Name     Sex    Age
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.00
# 796                        Leader, Dr. Alice (Farnham)  female  49.00
# 754                   Herman, Mrs. Samuel (Jane Laver)  female  48.00
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.00
# 736            Ford, Mrs. Edward (Margaret Ann Watson)  female  48.00
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# **OR operator**

# %%
df_sex = df["Sex"] == "Male"
df_age_mask = df["Age"] > 70
df[df_sex | df_age_mask]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age
# 630  male  80.0
# 851  male  74.0
# 493  male  71.0
# 96   male  71.0
# 116  male  70.5

# %% [markdown]
# # Finding the null values with .isnull()

# %%
null_mask = df["Age"].isnull()
df[null_mask]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age
# 5      male  NaN
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# dtype: int64

# %% [markdown]
# # Dropping a column

# %%
df.drop(labels = ["Pclass"], axis=1).head()
# Out:
#      PassengerId  Survived                                  Name   Sex   Age
# 630          631         1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
# 851          852         0                   Svensson, Mr. Johan  male  74.0
# 493          494         0               Artagaveytia, Mr. Ramon  male  71.0
# 96            97         0             Goldschmidt, Mr. George B  male  71.0
# 116          117         0                  Connors, Mr. Patrick  male  70.5

# %% [markdown]
# **Replacing the values by using the replace method**

# %%
df.replace("Nan",df["Age"].median())

df.replace("Masselmani, Mrs. Fatima", "Tanu")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex   Age
# 630    male  80.0
# ...

# %% [markdown]
# # Let us calculate how many passengers survived.
# Here 1 = survived, and 0 = Not survived.

# %%
count = df['Survived'].value_counts()
print(count)
# Let us see that in percentage.

percentage = df['Survived'].value_counts() * 100 / len(df)
print(percentage)
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# 0    61.616162
# 1    38.383838
# Name: Survived, dtype: float64

# %%
# %matplotlib inline
color = 0.5
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>
